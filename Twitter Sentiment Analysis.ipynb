# %%
import numpy as np
import pandas as pd

# %%
x_y_train = pd.read_csv('training_twitter_x_y_train.csv', delimiter=',')
x_test = pd.read_csv('test_twitter_x_test.csv', delimiter=',')

# %%
x_y_train.head()
# Out:
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
# 2  568089179520954368          positive     United                    NaN
# 3  568928195581513728          negative  Southwest                    NaN
# 4  568594180014014464          negative     United                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
# 2      LocalKyle                 NaN              0
# 3    amccarthy19                 NaN              0
# 4        J_Okayy                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
# 2  @united Flew ORD to Miami and back and  had gr...         NaN
# 3     @SouthwestAir @dultch97 that's horse radish 😤🐴         NaN
# 4  @united so our flight into ORD was delayed bec...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2  2015-02-18 08:46:29 -0800                    Illinois
# 3  2015-02-20 16:20:26 -0800                         NaN
# 4  2015-02-19 18:13:11 -0800                         NaN
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)
# 2  Central Time (US & Canada)
# 3      Atlantic Time (Canada)
# 4  Eastern Time (US & Canada)

# %%
train_data = x_y_train['text']
target_data = x_y_train['airline_sentiment']
print(target_data[4])
train_data[4]
# Out:
# negative
# '@united so our flight into ORD was delayed because of Air Force One, but the last flight to SBN is at 8:20, 5 mins from now we just landed.'

# %%
test_data_orig = x_test['text']
test_data_orig[0]
# Out:
# "@AmericanAir In car gng to DFW. Pulled over 1hr ago - very icy roads. On-hold with AA since 1hr. Can't reach arpt for AA2450. Wat 2 do?"

# %%
import nltk 
nltk.download('punkt')
from nltk.tokenize import word_tokenize
word_tokenize(train_data[4].lower())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Suchita\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ['@',
#  'united',
#  'so',
#  'our',
#  'flight',
#  'into',
#  'ord',
#  'was',
#  'delayed',
#  'because',
#  'of',
#  'air',
#  'force',
#  'one',
#  ',',
#  'but',
#  'the',
#  'last',
#  'flight',
#  'to',
#  'sbn',
#  'is',
#  'at',
#  '8:20',
#  ',',
#  '5',
#  'mins',
#  'from',
#  'now',
#  'we',
#  'just',
#  'landed',
#  '.']

# %%
documents = []
for i in range(len(train_data)):
    documents.append((word_tokenize(train_data[i].lower()), target_data[i]))
documents[8]
# Out:
# (['@',
#   'united',
#   'frankly',
#   'worse',
#   'customer',
#   'service',
#   'ever',
#   '.',
#   'problems',
#   'will',
#   'happen',
#   ',',
#   'how',
#   'you',
#   'deal',
#   'defines',
#   'a',
#   'company',
#   '.',
#   'never',
#   'again',
#   'united',
#   '.'],
#  'negative')

# %%
test_documents = []
for i in range(len(test_data_orig)):
    test_documents.append((word_tokenize(test_data_orig[i].lower())))
test_documents[0]
# Out:
# ['@',
#  'americanair',
#  'in',
#  'car',
#  'gng',
#  'to',
#  'dfw',
#  '.',
#  'pulled',
#  'over',
#  '1hr',
#  'ago',
#  '-',
#  'very',
#  'icy',
#  'roads',
#  '.',
#  'on-hold',
#  'with',
#  'aa',
#  'since',
#  '1hr',
#  '.',
#  'ca',
#  "n't",
#  'reach',
#  'arpt',
#  'for',
#  'aa2450',
#  '.',
#  'wat',
#  '2',
#  'do',
#  '?']

# %%
documents[70]
# Out:
# (['@',
#   'united',
#   'could',
#   'you',
#   'tell',
#   'me',
#   'if',
#   'this',
#   'bag',
#   'would',
#   'be',
#   'accepted',
#   'as',
#   'a',
#   'personal',
#   'item',
#   '?',
#   'can',
#   'i',
#   'bring',
#   'one',
#   'carry-on',
#   'bag',
#   'plus',
#   'this',
#   '?',
#   'http',
#   ':',
#   '//t.co/u390czplhl'],
#  'neutral')

# %%
import random
random.shuffle(documents)
documents[0:5]
# Out:
# [(['yes',
#    'but',
#    'i',
#    'will',
#    'nvr',
#    'fly',
#    'w/',
#    '@',
#    'usairways',
#    'i',
#    'missed',
#    'my',
#    'con',
#    'flight',
#    'bc',
#    'of',
#    'a',
#    'coffeemaker',
#    'on',
#    'ft1892',
#    'could',
#    "n't",
#    'see',
#    'my',
#    'father',
#    'be4',
#    'they',
#    'put',
#    'him',
#    'in',
#    'a',
#    'coma'],
#   'negative'),
#  (['@',
#    'usairways',
#    ',',
#    'i',
#    "'m",
#    'expecting',
#    '400',
#    '%',
#    'reimbursement',
#    'for',
#    'the',
#    'unprofessional',
#    'decisions',
#    'with',
#    'us728',
#    'on',
#    '21',
#    'feb.',
#    'check',
#    'your',
#    'very',
#    'full',
#    'complaint',
#    'box',
#    '.'],
#   'negative'),
#  (['@',
#    'united',
#    'not',
#    'fast',
#    'enough',
#    '.',
#    'no',
#    'excuse',
#    'for',
#    'service',
#    'between',
#    'big',
#    'hubs',
#    'to',
#    'have',
#    'such',
#    'outdated',
#    'craft',
#    '.',
#    'southwest',
#    'has',
#    'wifi',
#    '.',
#    'this',
#    'is',
#    'awful',
#    '.'],
#   'negative'),
#  (['@',
#    'united',
#    'i',
#    'can',
#    '’',
#    't',
#    'go',
#    'back',
#    'to',
#    'the',
#    'airport',
#    ',',
#    'i',
#    '’',
#    'm',
#    'working',
#    ',',
#    'and',
#    'won',
#    '’',
#    't',
#    'have',
#    'time',
#    '.',
#    'are',
#    'you',
#    'telling',
#    'me',
#    'there',
#    'is',
#    'seriously',
#    'no',
#    'other',
#    'way',
#    '?'],
#   'negative'),
#  (['@',
#    'united',
#    'male',
#    'agnt',
#    'in',
#    'las',
#    'threatens',
#    'canadian',
#    'cust',
#    'when',
#    'cust',
#    'takes',
#    'pic',
#    'of',
#    'him',
#    'at',
#    'gate',
#    'after',
#    'agents',
#    'announce',
#    'ca',
#    "n't",
#    'help',
#    'rebook',
#    '.',
#    '#',
#    'friendlyskies',
#    '?'],
#   'negative')]

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('v'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Suchita\AppData\Roaming\nltk_data...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk import pos_tag
w = 'better'
pos_tag([w])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Suchita\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [('better', 'RBR')]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Suchita\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
#   'hers',
#   'herself',
#   'him',
#   'himself',
#   'his',
#   'how',
#   'i',
#   'if',
#   'in',
#   'into',
#   'is',
#   'isn',
#   "isn't",
#   'it',
#   "it's",
#   'its',
#   'itself',
#   'just',
#   'll',
#   'm',
#   'ma',
#   'me',
#   'mightn',
#   "mightn't",
#   'more',
#   'most',
#   'mustn',
#   "mustn't",
#   'my',
#   'myself',
#   'needn',
#   "needn't",
#   'no',
#   'nor',
#   'not',
#   'now',
#   'o',
#   'of',
#   'off',
#   'on',
#   'once',
#   'only',
#   'or',
#   'other',
#   'our',
#   'ours',
#   'ourselves',
#   'out',
#   'over',
#   'own',
#   're',
#   's',
#   'same',
#   'shan',
#   "shan't",
#   'she',
#   "she's",
#   'should',
#   "should've",
#   'shouldn',
#   "shouldn't",
#   'so',
#   'some',
#   'such',
#   't',
#   'than',
#   'that',
#   "that'll",
#   'the',
#   'their',
#   'theirs',
#   'them',
#   'themselves',
#   'then',
#   'there',
#   'these',
#   'they',
#   'this',
#   'those',
#   'through',
#   'to',
#   'too',
#   'under',
#   'until',
#   'up',
#   've',
#   'very',
#   'was',
#   'wasn',
#   "wasn't",
#   'we',
#   'were',
#   'weren',
#   "weren't",
#   'what',
#   'when',
#   'where',
#   'which',
#   'while',
#   'who',
#   'whom',
#   'why',
#   'will',
#   'with',
#   'won',
#   "won't",
#   'wouldn',
#   "wouldn't",
#   'y',
#   'you',
#   "you'd",
#   "you'll",
#   "you're",
#   "you've",
#   'your',
#   'yours',
#   'yourself',
#   'yourselves',
#   '{',
#   '|',
#   '}',
#   '~'},
#  '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

# %%
import nltk
nltk.download('omw-1.4')
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Suchita\AppData\Roaming\nltk_data...

# %%
documents = [(clean_review(document), category) for document, category in documents]

# %%
documents[0]
# Out:
# (['yes',
#   'nvr',
#   'fly',
#   'w/',
#   'usairways',
#   'missed',
#   'con',
#   'flight',
#   'bc',
#   'coffeemaker',
#   'ft1892',
#   'could',
#   "n't",
#   'see',
#   'father',
#   'be4',
#   'put',
#   'coma'],
#  'negative')

# %%
len(documents)
# Out:
# 10980

# %%
len(test_documents)
# Out:
# 3660

# %% [markdown]
# # Sample training testing

# %%
training_documents_orig = documents
test_documents_orig = test_documents

training_documents = documents[0:7000]
test_documents = documents[7000:]

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %%
all_words_orig = []
for doc in training_documents_orig:
    all_words_orig += doc[0]

# %%
import nltk
freq = nltk.FreqDist(all_words)
common = freq.most_common(3000)
features = [i[0] for i in common]

# %%
import nltk
freq = nltk.FreqDist(all_words_orig)
common = freq.most_common(3000)
features_orig = [i[0] for i in common]

# %%
features
# Out:
# ['flight',
#  'united',
#  'americanair',
#  'usairways',
#  'southwestair',
#  'jetblue',
#  "n't",
#  "'s",
#  'get',
#  'http',
#  'hour',
#  'thanks',
#  'cancelled',
#  'u',
#  'service',
#  'customer',
#  'time',
#  'help',
#  '...',
#  'bag',
#  'plane',
#  'amp',
#  "'m",
#  'hold',
#  '2',
#  'thank',
#  'need',
#  'would',
#  'still',
#  'one',
#  'call',
#  'airline',
#  'gate',
#  'ca',
#  'day',
#  'please',
#  'back',
#  'virginamerica',
#  'flightled',
#  'delayed',
#  'bad',
#  'got',
#  'delay',
#  'seat',
#  "'ve",
#  "''",
#  'like',
#  '``',
#  'agent',
#  'phone',
#  'late',
#  'today',
#  'guy',
#  'airport',
#  'know',
#  'ticket',
#  'fly',
#  'make',
#  'waiting',
#  'could',
#  'trying',
#  'way',
#  'great',
#  'minute',
#  'change',
#  'go',
#  'well',
#  'wait',
#  'min',
#  'problem',
#  '3',
#  'take',
#  "'re",
#  'never',
#  'flying',
#  'going',
#  'hr',
#  'really',
#  'tomorrow',
#  'home',
#  '4',
#  'weather',
#  'dm',
#  'people',
#  'even',
#  'check',
#  'good',
#  'last',
#  'first',
#  'another',
#  'told',
#  'want',
#  'new',
#  'see',
#  'getting',
#  'lost',
#  'work',
#  "'ll",
#  'yes',
#  'luggage',
#  'email',
#  'love',
#  'someone',
#  'number',
#  'say',
#  'travel',
#  'much',
#  'reservation',
#  'let',
#  'due',
#  'issue',
#  '..',
#  'ever',
#  'next',
#  'trip',
#  'passenger',
#  'baggage',
#  'flighted',
#  'two',
#  'crew',
#  'made',
#  'right',
#  'experience',
#  'week',
#  'give',
#  'line',
#  'response',
#  'online',
#  'jfk',
#  'sent',
#  '”',
#  'sitting',
#  'said',
#  'staff',
#  'aa',
#  'booked',
#  'best',
#  '“',
#  'already',
#  'long',
#  'connection',
#  'book',
#  'sure',
#  '1',
#  'keep',
#  'left',
#  'wo',
#  'boarding',
#  'look',
#  'since',
#  'mile',
#  'night',
#  'tonight',
#  'morning',
#  'stuck',
#  'tell',
#  '5',
#  'find',
#  'miss',
#  'website',
#  'use',
#  'flightr',
#  'care',
#  'put',
#  'anything',
#  'info',
#  'refund',
#  'think',
#  "'d",
#  'year',
#  'nothing',
#  'answer',
#  'yet',
#  'hope',
#  'pay',
#  'booking',
#  'system',
#  'fleek',
#  'hotel',
#  'attendant',
#  'flt',
#  'dfw',
#  'voucher',
#  'tried',
#  'fleet',
#  'class',
#  'follow',
#  'rebooked',
#  'free',
#  'air',
#  'nice',
#  'pilot',
#  'update',
#  'ago',
#  'missed',
#  'able',
#  'rude',
#  '’',
#  'finally',
#  'called',
#  'rebook',
#  'rep',
#  'checked',
#  'wifi',
#  'done',
#  'business',
#  'upgrade',
#  'point',
#  'anyone',
#  'thing',
#  '....',
#  'fee',
#  'looking',
#  'come',
#  'person',
#  'via',
#  'also',
#  '30',
#  'missing',
#  'always',
#  'every',
#  'awesome',
#  'board',
#  'option',
#  'lax',
#  'employee',
#  'credit',
#  'appreciate',
#  'team',
#  'app',
#  '6',
#  'terrible',
#  'southwest',
#  'status',
#  'delta',
#  'understand',
#  'gt',
#  'show',
#  'yesterday',
#  '1st',
#  '20',
#  '10',
#  'mean',
#  'without',
#  'working',
#  'claim',
#  'making',
#  'thx',
#  'suck',
#  'leave',
#  'instead',
#  'happy',
#  'sorry',
#  'send',
#  'friend',
#  'disappointed',
#  'ok',
#  'name',
#  'earlier',
#  'open',
#  'speak',
#  'almost',
#  'many',
#  'full',
#  'money',
#  'took',
#  'ridiculous',
#  'phl',
#  'dca',
#  'helpful',
#  'fail',
#  'sfo',
#  'something',
#  'airway',
#  'extra',
#  'talk',
#  'try',
#  'connecting',
#  'rt',
#  'member',
#  'amazing',
#  'pas',
#  'departure',
#  'unacceptable',
#  'hung',
#  'policy',
#  'add',
#  'oh',
#  'wife',
#  'stranded',
#  'la',
#  'family',
#  'hi',
#  'though',
#  'available',
#  'reason',
#  'site',
#  'ground',
#  'lot',
#  'fix',
#  'seriously',
#  'everyone',
#  'paid',
#  'company',
#  'month',
#  'least',
#  'early',
#  'direct',
#  'old',
#  'stop',
#  'found',
#  'tweet',
#  'vega',
#  'chicago',
#  'horrible',
#  'ord',
#  'taking',
#  'card',
#  'supposed',
#  'message',
#  'snow',
#  'dallas',
#  'ewr',
#  'contact',
#  'denver',
#  'food',
#  'ur',
#  'big',
#  'san',
#  'chance',
#  'kid',
#  'received',
#  'twitter',
#  'clt',
#  'w/',
#  'offer',
#  'question',
#  'past',
#  'actually',
#  'tarmac',
#  'charge',
#  'calling',
#  'boston',
#  'sit',
#  'different',
#  'row',
#  'destinationdragons',
#  'away',
#  'saying',
#  'poor',
#  '--',
#  'wrong',
#  'account',
#  'cost',
#  'leaving',
#  'start',
#  'desk',
#  'bos',
#  'american',
#  'might',
#  'job',
#  'phx',
#  'enough',
#  'link',
#  'complaint',
#  '7',
#  'maybe',
#  'twice',
#  'hey',
#  'little',
#  '45',
#  'stay',
#  'asked',
#  'car',
#  'telling',
#  'reply',
#  'soon',
#  'far',
#  'runway',
#  '8',
#  'changed',
#  'landed',
#  'three',
#  'return',
#  'around',
#  'went',
#  '50',
#  'gave',
#  'confirmation',
#  'frustrated',
#  'guess',
#  'using',
#  'terminal',
#  'iad',
#  'destination',
#  'nyc',
#  'used',
#  'feel',
#  'waited',
#  'may',
#  'believe',
#  'city',
#  'coming',
#  '40',
#  'price',
#  'possible',
#  'plan',
#  'bc',
#  'plus',
#  'traveling',
#  'together',
#  'cool',
#  'im',
#  'charlotte',
#  'thought',
#  'seems',
#  'swa',
#  'else',
#  'computer',
#  'second',
#  'less',
#  'real',
#  'idea',
#  'high',
#  'w',
#  '200',
#  'deal',
#  'hard',
#  'landing',
#  'thru',
#  'room',
#  'vacation',
#  'frustrating',
#  'end',
#  'houston',
#  'place',
#  'longer',
#  'newark',
#  'hang',
#  'apology',
#  'sat',
#  'tv',
#  'hear',
#  '15',
#  'arrive',
#  'happened',
#  'mechanical',
#  'half',
#  'na',
#  'easy',
#  'reach',
#  'process',
#  'broken',
#  'arrived',
#  'fare',
#  'error',
#  'assistance',
#  'busy',
#  'philly',
#  'group',
#  'flyer',
#  'fll',
#  'international',
#  'ua',
#  'cust',
#  'scheduled',
#  'heard',
#  'dc',
#  'counting',
#  'leg',
#  'date',
#  'awful',
#  'forward',
#  'club',
#  'award',
#  'given',
#  'lga',
#  'reflight',
#  'joke',
#  'lol',
#  'child',
#  'maintenance',
#  'request',
#  'jet',
#  'appreciated',
#  'glad',
#  'lack',
#  'bring',
#  'traveler',
#  'pls',
#  'human',
#  'monday',
#  'miami',
#  'rock',
#  'ask',
#  'b',
#  'lt',
#  'lose',
#  'iah',
#  'paying',
#  'information',
#  'flew',
#  'spent',
#  '25',
#  'everything',
#  'checking',
#  '2nd',
#  'standby',
#  "y'all",
#  'situation',
#  'run',
#  'tsa',
#  'loyal',
#  'respond',
#  '1/2',
#  'quick',
#  'drive',
#  'carry',
#  'cause',
#  '24',
#  'hoping',
#  'hopefully',
#  'storm',
#  'blue',
#  'ceo',
#  'original',
#  'yeah',
#  'super',
#  'case',
#  'platinum',
#  'wow',
#  'fine',
#  'companion',
#  'expect',
#  'word',
#  'switch',
#  'seem',
#  'wtf',
#  'supervisor',
#  'entire',
#  'whole',
#  'pick',
#  'bwi',
#  'medium',
#  'luv',
#  'currently',
#  'rather',
#  'imaginedragons',
#  'wanted',
#  'okay',
#  'priority',
#  'boarded',
#  '800',
#  'atl',
#  'unitedairlines',
#  'sunday',
#  'asking',
#  'usair',
#  '9',
#  'cant',
#  'counter',
#  'wish',
#  'correct',
#  'orlando',
#  'flightlations',
#  'beyond',
#  'detail',
#  'communication',
#  'husband',
#  'live',
#  'safety',
#  'helping',
#  'part',
#  'treat',
#  'empty',
#  'completely',
#  'provide',
#  'world',
#  'asap',
#  'apparently',
#  'holding',
#  'figure',
#  'life',
#  'fixed',
#  'must',
#  'flighting',
#  'offered',
#  'drink',
#  'lie',
#  'hate',
#  'load',
#  'reschedule',
#  'form',
#  'fun',
#  'austin',
#  'sleep',
#  'worry',
#  '1.5',
#  'gon',
#  'middle',
#  'r',
#  'happen',
#  'moved',
#  '12',
#  'disconnected',
#  'upset',
#  'purchase',
#  'buy',
#  'pretty',
#  'address',
#  'zero',
#  'nashville',
#  'list',
#  'several',
#  'helped',
#  'taken',
#  'land',
#  'tuesday',
#  'c',
#  'dont',
#  'space',
#  'happens',
#  'door',
#  'ready',
#  'kind',
#  '100',
#  'losing',
#  'flown',
#  'yr',
#  'support',
#  'access',
#  'small',
#  'top',
#  'future',
#  'mom',
#  'customerservice',
#  '11',
#  'probably',
#  'needed',
#  'explain',
#  'compensation',
#  'answering',
#  'confirmed',
#  'delivered',
#  'route',
#  'matter',
#  'despite',
#  'running',
#  'water',
#  'spoke',
#  'allow',
#  'report',
#  'fault',
#  '1k',
#  'share',
#  'aircraft',
#  'huge',
#  'news',
#  'page',
#  'sw',
#  'dividend',
#  'overhead',
#  'automated',
#  'virgin',
#  'mine',
#  'responding',
#  'cold',
#  'item',
#  'knew',
#  'unable',
#  'following',
#  'atlanta',
#  'den',
#  'clothes',
#  'cover',
#  'mileage',
#  'absolutely',
#  'daughter',
#  'id',
#  'either',
#  'schedule',
#  'changing',
#  'course',
#  'notification',
#  'country',
#  'checkin',
#  'arrival',
#  'sad',
#  'haha',
#  'record',
#  'yall',
#  'fact',
#  'overnight',
#  'inconvenience',
#  'giving',
#  'handle',
#  'meal',
#  'attitude',
#  'rescheduled',
#  'son',
#  'mess',
#  'set',
#  'complete',
#  'extremely',
#  'man',
#  'learn',
#  'baby',
#  'drop',
#  'luck',
#  'code',
#  'check-in',
#  'unfortunately',
#  'confirm',
#  'note',
#  'usairwaysfail',
#  'read',
#  'sending',
#  'program',
#  'folk',
#  'area',
#  'lounge',
#  'excited',
#  'birthday',
#  'connect',
#  'saw',
#  'letting',
#  'treated',
#  'kept',
#  'seen',
#  'rate',
#  'multiple',
#  'friday',
#  'fl',
#  'bought',
#  'true',
#  '2015',
#  'watch',
#  'step',
#  'flightlation',
#  'layover',
#  'b/c',
#  'wonderful',
#  'mco',
#  'excuse',
#  'failure',
#  'allowed',
#  'dragon',
#  'social',
#  'trouble',
#  'concern',
#  'acceptable',
#  'mobile',
#  'charged',
#  'hello',
#  'forced',
#  'sign',
#  '3rd',
#  'afternoon',
#  'none',
#  'showing',
#  'fan',
#  'story',
#  'frequent',
#  'resolved',
#  'resolve',
#  'receive',
#  'failed',
#  'caused',
#  'depart',
#  'choice',
#  'totally',
#  'mistake',
#  'front',
#  'crazy',
#  'tag',
#  'enjoy',
#  'close',
#  'volume',
#  'refuse',
#  'cabin',
#  'arriving',
#  'happening',
#  'gold',
#  'file',
#  'web',
#  'shit',
#  'excellent',
#  'dealing',
#  'pm',
#  'rdu',
#  'round',
#  'explanation',
#  'mind',
#  'held',
#  'tix',
#  '2hrs',
#  'came',
#  '2.5',
#  'non',
#  'receipt',
#  'office',
#  'neveragain',
#  'bna',
#  'kudos',
#  'merger',
#  'americanairlines',
#  'tmrw',
#  'winter',
#  'evening',
#  'ice',
#  'bank',
#  'warm',
#  'submitted',
#  'started',
#  '75',
#  'behind',
#  'offering',
#  'touch',
#  'four',
#  'unhappy',
#  'especially',
#  'post',
#  'wall',
#  'lady',
#  'window',
#  '90',
#  'btw',
#  'entertainment',
#  'ruined',
#  'plz',
#  'mia',
#  'ppl',
#  'gone',
#  '2+',
#  'others',
#  'philadelphia',
#  'phoenix',
#  'ny',
#  'nope',
#  'bumped',
#  'willing',
#  'relation',
#  'closed',
#  'move',
#  'tired',
#  'added',
#  'catch',
#  'spend',
#  'followed',
#  'short',
#  'transfer',
#  'weekend',
#  'view',
#  'funeral',
#  'nonstop',
#  'friendly',
#  'video',
#  'worth',
#  'itinerary',
#  'callback',
#  'emergency',
#  'updated',
#  'bus',
#  'current',
#  'low',
#  'sick',
#  'moving',
#  'seating',
#  'visit',
#  'feb',
#  'order',
#  'anyway',
#  'denied',
#  'finger',
#  'saturday',
#  'wondering',
#  'letter',
#  'text',
#  'bin',
#  'mention',
#  'sound',
#  'count',
#  'broke',
#  'solution',
#  'turn',
#  'airplane',
#  'unhelpful',
#  'favorite',
#  'center',
#  'fuck',
#  'cut',
#  'march',
#  'head',
#  'suggestion',
#  'per',
#  'funny',
#  'final',
#  'captain',
#  'announcement',
#  'train',
#  'ended',
#  'tho',
#  'hand',
#  'svc',
#  'conf',
#  'dollar',
#  'notice',
#  'assist',
#  'special',
#  'enter',
#  'takeoff',
#  'filed',
#  'bit',
#  'department',
#  'flightd',
#  'literally',
#  'imagine',
#  'seattle',
#  'control',
#  'sense',
#  'tweeting',
#  'resolution',
#  'save',
#  'kidding',
#  'safe',
#  'badservice',
#  'inflight',
#  'win',
#  'break',
#  'useless',
#  'sort',
#  'definitely',
#  'onto',
#  'power',
#  'match',
#  '.....',
#  'america',
#  'pathetic',
#  'state',
#  'actual',
#  'reward',
#  'large',
#  'talked',
#  'fyi',
#  'auto',
#  'inside',
#  'surprise',
#  'departing',
#  'clear',
#  'worked',
#  'hell',
#  'except',
#  'nightmare',
#  'security',
#  'oscar',
#  'trust',
#  'damn',
#  'brand',
#  'fast',
#  'engine',
#  'planned',
#  'equipment',
#  'fair',
#  'effort',
#  'photo',
#  'incredibly',
#  'internet',
#  'impressed',
#  'however',
#  'smh',
#  'florida',
#  'diego',
#  'snack',
#  'clearly',
#  'serious',
#  'expected',
#  'representative',
#  'anymore',
#  'discount',
#  'anywhere',
#  'carrier',
#  'select',
#  'premier',
#  'n',
#  'freezing',
#  'south',
#  'dept',
#  'delivery',
#  'expensive',
#  'angry',
#  'w/o',
#  'compensate',
#  'consider',
#  'fit',
#  'answered',
#  'game',
#  'handled',
#  'ugh',
#  'avgeek',
#  'notified',
#  ...]

# %%
features_orig
# Out:
# ['flight',
#  'united',
#  'usairways',
#  'americanair',
#  'southwestair',
#  'jetblue',
#  "n't",
#  "'s",
#  'get',
#  'http',
#  'hour',
#  'thanks',
#  'cancelled',
#  'u',
#  'service',
#  'customer',
#  'time',
#  'help',
#  '...',
#  'bag',
#  'plane',
#  'amp',
#  "'m",
#  'hold',
#  'need',
#  '2',
#  'thank',
#  'would',
#  'still',
#  'one',
#  'call',
#  'airline',
#  'gate',
#  'day',
#  'please',
#  'ca',
#  'back',
#  'delayed',
#  'virginamerica',
#  'flightled',
#  'bad',
#  'got',
#  "'ve",
#  'delay',
#  'seat',
#  "''",
#  '``',
#  'like',
#  'agent',
#  'phone',
#  'late',
#  'today',
#  'guy',
#  'ticket',
#  'fly',
#  'know',
#  'make',
#  'waiting',
#  'airport',
#  'could',
#  'trying',
#  'minute',
#  'way',
#  'great',
#  'change',
#  'well',
#  '3',
#  'never',
#  'going',
#  'go',
#  'wait',
#  'flying',
#  'min',
#  'problem',
#  'really',
#  'home',
#  'take',
#  'hr',
#  "'re",
#  'tomorrow',
#  '4',
#  'dm',
#  'weather',
#  'last',
#  'even',
#  'good',
#  'another',
#  'people',
#  'check',
#  'new',
#  'see',
#  'first',
#  'told',
#  'work',
#  'want',
#  'getting',
#  'issue',
#  "'ll",
#  'love',
#  'lost',
#  'say',
#  'email',
#  'yes',
#  'luggage',
#  'much',
#  'ever',
#  'due',
#  'number',
#  'next',
#  'travel',
#  'someone',
#  'let',
#  'reservation',
#  '..',
#  'trip',
#  'flighted',
#  'baggage',
#  'crew',
#  'two',
#  'passenger',
#  'made',
#  'line',
#  'response',
#  'experience',
#  'week',
#  'right',
#  'give',
#  'aa',
#  'online',
#  'jfk',
#  '”',
#  'sent',
#  'best',
#  'sitting',
#  'said',
#  'booked',
#  '“',
#  'staff',
#  'book',
#  'connection',
#  'already',
#  'long',
#  '1',
#  'boarding',
#  'sure',
#  'look',
#  'keep',
#  'wo',
#  'morning',
#  'mile',
#  'since',
#  'left',
#  'miss',
#  'tonight',
#  'website',
#  'flightr',
#  'stuck',
#  'tell',
#  '5',
#  'put',
#  'find',
#  'night',
#  'use',
#  'info',
#  'year',
#  'think',
#  'care',
#  'hope',
#  "'d",
#  'flt',
#  'anything',
#  'yet',
#  'tried',
#  'hotel',
#  'answer',
#  'fleek',
#  'pay',
#  'refund',
#  'nothing',
#  'system',
#  'fleet',
#  'booking',
#  'voucher',
#  'dfw',
#  'missed',
#  'update',
#  'rebooked',
#  'attendant',
#  'follow',
#  'rude',
#  'air',
#  'nice',
#  'class',
#  'called',
#  '’',
#  'free',
#  'rebook',
#  'finally',
#  'pilot',
#  'ago',
#  'able',
#  'also',
#  'business',
#  'done',
#  'checked',
#  'thing',
#  'point',
#  'wifi',
#  'fee',
#  'rep',
#  'option',
#  'upgrade',
#  'always',
#  'board',
#  'via',
#  'missing',
#  'team',
#  'looking',
#  'come',
#  'credit',
#  'every',
#  'person',
#  'awesome',
#  '....',
#  'anyone',
#  '6',
#  'appreciate',
#  '30',
#  'lax',
#  'yesterday',
#  'employee',
#  'status',
#  'delta',
#  'making',
#  'working',
#  'southwest',
#  'suck',
#  'thx',
#  'terrible',
#  'gt',
#  'mean',
#  'leave',
#  'app',
#  'show',
#  'claim',
#  'understand',
#  'helpful',
#  '1st',
#  'without',
#  '20',
#  'sfo',
#  'instead',
#  'friend',
#  '10',
#  'fail',
#  'sorry',
#  'earlier',
#  'dca',
#  'open',
#  'disappointed',
#  'money',
#  'happy',
#  'ok',
#  'talk',
#  'name',
#  'speak',
#  'something',
#  'airway',
#  'extra',
#  'phl',
#  'departure',
#  'full',
#  'though',
#  'ridiculous',
#  'many',
#  'hung',
#  'send',
#  'took',
#  'almost',
#  'amazing',
#  'oh',
#  'available',
#  'add',
#  'pas',
#  'connecting',
#  'fix',
#  'reason',
#  'try',
#  'early',
#  'card',
#  'lot',
#  'member',
#  'unacceptable',
#  'ord',
#  'site',
#  'hi',
#  'supposed',
#  'horrible',
#  'la',
#  'family',
#  'chicago',
#  'rt',
#  'paid',
#  'wife',
#  'stranded',
#  'taking',
#  'least',
#  'big',
#  'ground',
#  'question',
#  'everyone',
#  'ewr',
#  'received',
#  'direct',
#  'policy',
#  'poor',
#  'old',
#  'clt',
#  'seriously',
#  'vega',
#  'twitter',
#  'stop',
#  'company',
#  'dallas',
#  'month',
#  'contact',
#  'chance',
#  'denver',
#  'san',
#  'w/',
#  'tweet',
#  'calling',
#  'food',
#  'message',
#  'ur',
#  'snow',
#  'kid',
#  'past',
#  'little',
#  'actually',
#  'boston',
#  'start',
#  'tarmac',
#  'charge',
#  'different',
#  'found',
#  'destinationdragons',
#  'job',
#  '7',
#  'desk',
#  'bos',
#  'sit',
#  'maybe',
#  'offer',
#  'cost',
#  'american',
#  '--',
#  '45',
#  'far',
#  'account',
#  'asked',
#  'landed',
#  'might',
#  'hey',
#  'leaving',
#  'away',
#  '8',
#  'wrong',
#  'enough',
#  'twice',
#  'saying',
#  'row',
#  'complaint',
#  'return',
#  'three',
#  'confirmation',
#  'may',
#  'changed',
#  'phx',
#  'link',
#  'coming',
#  'reply',
#  'destination',
#  'using',
#  'gave',
#  'car',
#  'telling',
#  'soon',
#  'charlotte',
#  'around',
#  '50',
#  'frustrated',
#  'stay',
#  'went',
#  '40',
#  'waited',
#  'runway',
#  'iad',
#  'city',
#  'guess',
#  'less',
#  'bc',
#  'broken',
#  'believe',
#  'w',
#  'nyc',
#  'together',
#  'possible',
#  'cool',
#  'computer',
#  'traveling',
#  'vacation',
#  'hard',
#  'feel',
#  'else',
#  'plan',
#  'real',
#  'plus',
#  'thought',
#  'seems',
#  'terminal',
#  'second',
#  'longer',
#  'landing',
#  'im',
#  'sat',
#  'used',
#  'price',
#  'idea',
#  'half',
#  '200',
#  'deal',
#  'swa',
#  'hear',
#  'newark',
#  'end',
#  'process',
#  'mechanical',
#  'place',
#  'error',
#  'easy',
#  'frustrating',
#  '15',
#  'houston',
#  'high',
#  'arrive',
#  'happened',
#  'thru',
#  'room',
#  'tv',
#  'awful',
#  'assistance',
#  'group',
#  'monday',
#  'na',
#  'hang',
#  'lol',
#  'international',
#  'ua',
#  'cust',
#  'philly',
#  'apology',
#  'arrived',
#  'flyer',
#  'scheduled',
#  'fare',
#  'jet',
#  'date',
#  'pls',
#  'reach',
#  'busy',
#  '25',
#  'forward',
#  'joke',
#  'standby',
#  'heard',
#  'fll',
#  'award',
#  'counting',
#  'request',
#  'given',
#  'human',
#  'miami',
#  'appreciated',
#  'lack',
#  'dc',
#  'club',
#  'leg',
#  'glad',
#  'reflight',
#  'checking',
#  'iah',
#  'carry',
#  'child',
#  'bring',
#  'traveler',
#  'maintenance',
#  'word',
#  'lga',
#  'rock',
#  'everything',
#  'paying',
#  'b',
#  'hoping',
#  '1/2',
#  'wanted',
#  'quick',
#  '2nd',
#  "y'all",
#  'information',
#  'lose',
#  'spent',
#  '24',
#  'unitedairlines',
#  'sunday',
#  'super',
#  'ask',
#  'drive',
#  'asking',
#  'cause',
#  'companion',
#  'blue',
#  'flew',
#  'expect',
#  'run',
#  'lt',
#  'usair',
#  'switch',
#  '800',
#  'supervisor',
#  'respond',
#  'entire',
#  'helping',
#  'case',
#  'storm',
#  'situation',
#  'boarded',
#  'medium',
#  'tsa',
#  'rather',
#  '9',
#  'loyal',
#  'wtf',
#  'cant',
#  'worry',
#  'counter',
#  'okay',
#  'detail',
#  'hate',
#  'bwi',
#  'ceo',
#  'luv',
#  'currently',
#  'seem',
#  'life',
#  'atl',
#  'live',
#  '12',
#  'must',
#  'offered',
#  'part',
#  'correct',
#  'platinum',
#  'wow',
#  'hopefully',
#  'whole',
#  'empty',
#  'provide',
#  'world',
#  'pick',
#  'load',
#  'fine',
#  'communication',
#  'husband',
#  'pretty',
#  'address',
#  'route',
#  'original',
#  'figure',
#  'yeah',
#  'imaginedragons',
#  'safety',
#  'probably',
#  'wish',
#  'flighting',
#  'priority',
#  'beyond',
#  'completely',
#  'r',
#  'apparently',
#  'form',
#  'door',
#  'moved',
#  'ready',
#  'taken',
#  'disconnected',
#  'fixed',
#  'needed',
#  '100',
#  'middle',
#  'support',
#  'orlando',
#  'flightlations',
#  'treat',
#  'lie',
#  'asap',
#  'holding',
#  'list',
#  'sleep',
#  'land',
#  '1.5',
#  'tuesday',
#  'gon',
#  'flown',
#  'answering',
#  'access',
#  'small',
#  'top',
#  'dont',
#  'fault',
#  'zero',
#  'reschedule',
#  'fun',
#  'happen',
#  'austin',
#  'helped',
#  'checkin',
#  'drink',
#  'purchase',
#  'buy',
#  'allow',
#  'record',
#  'space',
#  'future',
#  'mom',
#  'nashville',
#  'several',
#  'huge',
#  'handle',
#  'dividend',
#  'running',
#  '11',
#  'notification',
#  'story',
#  'kind',
#  'explain',
#  'compensation',
#  'losing',
#  'yr',
#  'multiple',
#  'read',
#  'upset',
#  'cold',
#  'item',
#  'delivered',
#  'yall',
#  'share',
#  'despite',
#  'atlanta',
#  'either',
#  'den',
#  'meal',
#  'schedule',
#  'water',
#  'automated',
#  'c',
#  'arrival',
#  'confirmed',
#  'responding',
#  'haha',
#  'knew',
#  'report',
#  '1k',
#  'happens',
#  'overnight',
#  'mobile',
#  'area',
#  'extremely',
#  'birthday',
#  'matter',
#  'aircraft',
#  'giving',
#  'customerservice',
#  'following',
#  'learn',
#  'flightlation',
#  'page',
#  'sw',
#  'changing',
#  'attitude',
#  'overhead',
#  'clothes',
#  'treated',
#  'country',
#  'seen',
#  'virgin',
#  'luck',
#  'rescheduled',
#  'son',
#  'unfortunately',
#  'mine',
#  'note',
#  'spoke',
#  'shit',
#  'sad',
#  'set',
#  'bought',
#  'daughter',
#  'unable',
#  'fact',
#  'charged',
#  'lounge',
#  'excited',
#  'man',
#  'news',
#  'front',
#  'course',
#  'mco',
#  'mileage',
#  'code',
#  'failure',
#  'friday',
#  'mess',
#  'absolutely',
#  'sending',
#  'dealing',
#  'rdu',
#  'social',
#  'concern',
#  'folk',
#  '2015',
#  'choice',
#  'winter',
#  'watch',
#  'sign',
#  'id',
#  'totally',
#  'baby',
#  'afternoon',
#  'layover',
#  'b/c',
#  'crazy',
#  'office',
#  'excuse',
#  'tag',
#  'kept',
#  'kudos',
#  'check-in',
#  'nope',
#  'confirm',
#  'allowed',
#  'unhappy',
#  'fl',
#  'dragon',
#  'pm',
#  'true',
#  'complete',
#  'trouble',
#  'program',
#  'acceptable',
#  'hello',
#  'forced',
#  'spend',
#  'mind',
#  'mistake',
#  'tix',
#  'showing',
#  'came',
#  'wonderful',
#  'non',
#  'cover',
#  'refuse',
#  'cabin',
#  'drop',
#  'rate',
#  'ny',
#  'arriving',
#  'frequent',
#  'four',
#  'usairwaysfail',
#  'gold',
#  'americanairlines',
#  'evening',
#  'explanation',
#  'inconvenience',
#  'step',
#  '3rd',
#  'none',
#  'held',
#  'connect',
#  'ruined',
#  'submitted',
#  'fan',
#  '2.5',
#  'started',
#  'saw',
#  'ppl',
#  'letting',
#  'enjoy',
#  'close',
#  'bna',
#  'web',
#  'turn',
#  'merger',
#  'relation',
#  'resolve',
#  'especially',
#  'receive',
#  'sense',
#  'post',
#  'failed',
#  'depart',
#  'lady',
#  'window',
#  'order',
#  'round',
#  'anyway',
#  'entertainment',
#  'plz',
#  'mia',
#  'funeral',
#  'sound',
#  'neveragain',
#  'friendly',
#  '75',
#  'volume',
#  'behind',
#  'offering',
#  'others',
#  'philadelphia',
#  'phoenix',
#  'bumped',
#  'itinerary',
#  'happening',
#  'resolved',
#  'updated',
#  'excellent',
#  'state',
#  'flightd',
#  'literally',
#  'move',
#  'tmrw',
#  'unhelpful',
#  'control',
#  'low',
#  'favorite',
#  'caused',
#  'seating',
#  'kidding',
#  'feb',
#  '90',
#  'finger',
#  'catch',
#  'btw',
#  'saturday',
#  'bank',
#  'captain',
#  'followed',
#  'short',
#  'passbook',
#  'letter',
#  'warm',
#  'train',
#  '2hrs',
#  'weekend',
#  'receipt',
#  'video',
#  'special',
#  'solution',
#  'file',
#  'emergency',
#  'advisory',
#  'closed',
#  'airplane',
#  'current',
#  'impressed',
#  'moving',
#  'center',
#  'wall',
#  'safe',
#  'ice',
#  'break',
#  'march',
#  'suggestion',
#  '1hr',
#  'final',
#  'wondering',
#  'transfer',
#  'definitely',
#  'onto',
#  'mention',
#  'trust',
#  'view',
#  'anymore',
#  'tho',
#  'hand',
#  'match',
#  'gone',
#  'count',
#  'svc',
#  '2+',
#  'woman',
#  'touch',
#  'dollar',
#  'worth',
#  'assist',
#  'equipment',
#  'filed',
#  'pathetic',
#  'bus',
#  'imagine',
#  'sick',
#  'visit',
#  'auto',
#  'badservice',
#  'fuck',
#  'compensate',
#  'cut',
#  'win',
#  'tired',
#  'denied',
#  'head',
#  'added',
#  'avgeek',
#  'per',
#  'funny',
#  'clearly',
#  'announcement',
#  'useless',
#  'text',
#  'hell',
#  'except',
#  'bin',
#  'expected',
#  'representative',
#  'nonstop',
#  'god',
#  'wasted',
#  'major',
#  'fast',
#  'premier',
#  'conf',
#  'planned',
#  '.....',
#  'broke',
#  'notice',
#  'ride',
#  'callback',
#  'takeoff',
#  'exit',
#  'willing',
#  'effort',
#  'photo',
#  'bit',
#  'department',
#  'actual',
#  'seattle',
#  'internet',
#  'reward',
#  'talked',
#  'tweeting',
#  'resolution',
#  'smh',
#  'save',
#  'impossible',
#  'w/o',
#  'inflight',
#  'inside',
#  'game',
#  'ugh',
#  'clear',
#  'worked',
#  'stuff',
#  'slow',
#  'sort',
#  'welcome',
#  'ended',
#  'nightmare',
#  'security',
#  'oscar',
#  'sell',
#  'power',
#  'damn',
#  'carrier',
#  'select',
#  'coffee',
#  'domestic',
#  'sky',
#  'absolute',
#  'america',
#  'south',
#  'fair',
#  'preferred',
#  'dept',
#  'incredibly',
#  'disconnect',
#  'onboard',
#  'deliver',
#  'however',
#  'fyi',
#  ...]

# %%
def get_feature_dict(words):
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
output = get_feature_dict(training_documents[0][0])
output
# Out:
# {'flight': True,
#  'united': False,
#  'americanair': False,
#  'usairways': True,
#  'southwestair': False,
#  'jetblue': False,
#  "n't": True,
#  "'s": False,
#  'get': False,
#  'http': False,
#  'hour': False,
#  'thanks': False,
#  'cancelled': False,
#  'u': False,
#  'service': False,
#  'customer': False,
#  'time': False,
#  'help': False,
#  '...': False,
#  'bag': False,
#  'plane': False,
#  'amp': False,
#  "'m": False,
#  'hold': False,
#  '2': False,
#  'thank': False,
#  'need': False,
#  'would': False,
#  'still': False,
#  'one': False,
#  'call': False,
#  'airline': False,
#  'gate': False,
#  'ca': False,
#  'day': False,
#  'please': False,
#  'back': False,
#  'virginamerica': False,
#  'flightled': False,
#  'delayed': False,
#  'bad': False,
#  'got': False,
#  'delay': False,
#  'seat': False,
#  "'ve": False,
#  "''": False,
#  'like': False,
#  '``': False,
#  'agent': False,
#  'phone': False,
#  'late': False,
#  'today': False,
#  'guy': False,
#  'airport': False,
#  'know': False,
#  'ticket': False,
#  'fly': True,
#  'make': False,
#  'waiting': False,
#  'could': True,
#  'trying': False,
#  'way': False,
#  'great': False,
#  'minute': False,
#  'change': False,
#  'go': False,
#  'well': False,
#  'wait': False,
#  'min': False,
#  'problem': False,
#  '3': False,
#  'take': False,
#  "'re": False,
#  'never': False,
#  'flying': False,
#  'going': False,
#  'hr': False,
#  'really': False,
#  'tomorrow': False,
#  'home': False,
#  '4': False,
#  'weather': False,
#  'dm': False,
#  'people': False,
#  'even': False,
#  'check': False,
#  'good': False,
#  'last': False,
#  'first': False,
#  'another': False,
#  'told': False,
#  'want': False,
#  'new': False,
#  'see': True,
#  'getting': False,
#  'lost': False,
#  'work': False,
#  "'ll": False,
#  'yes': True,
#  'luggage': False,
#  'email': False,
#  'love': False,
#  'someone': False,
#  'number': False,
#  'say': False,
#  'travel': False,
#  'much': False,
#  'reservation': False,
#  'let': False,
#  'due': False,
#  'issue': False,
#  '..': False,
#  'ever': False,
#  'next': False,
#  'trip': False,
#  'passenger': False,
#  'baggage': False,
#  'flighted': False,
#  'two': False,
#  'crew': False,
#  'made': False,
#  'right': False,
#  'experience': False,
#  'week': False,
#  'give': False,
#  'line': False,
#  'response': False,
#  'online': False,
#  'jfk': False,
#  'sent': False,
#  '”': False,
#  'sitting': False,
#  'said': False,
#  'staff': False,
#  'aa': False,
#  'booked': False,
#  'best': False,
#  '“': False,
#  'already': False,
#  'long': False,
#  'connection': False,
#  'book': False,
#  'sure': False,
#  '1': False,
#  'keep': False,
#  'left': False,
#  'wo': False,
#  'boarding': False,
#  'look': False,
#  'since': False,
#  'mile': False,
#  'night': False,
#  'tonight': False,
#  'morning': False,
#  'stuck': False,
#  'tell': False,
#  '5': False,
#  'find': False,
#  'miss': False,
#  'website': False,
#  'use': False,
#  'flightr': False,
#  'care': False,
#  'put': True,
#  'anything': False,
#  'info': False,
#  'refund': False,
#  'think': False,
#  "'d": False,
#  'year': False,
#  'nothing': False,
#  'answer': False,
#  'yet': False,
#  'hope': False,
#  'pay': False,
#  'booking': False,
#  'system': False,
#  'fleek': False,
#  'hotel': False,
#  'attendant': False,
#  'flt': False,
#  'dfw': False,
#  'voucher': False,
#  'tried': False,
#  'fleet': False,
#  'class': False,
#  'follow': False,
#  'rebooked': False,
#  'free': False,
#  'air': False,
#  'nice': False,
#  'pilot': False,
#  'update': False,
#  'ago': False,
#  'missed': True,
#  'able': False,
#  'rude': False,
#  '’': False,
#  'finally': False,
#  'called': False,
#  'rebook': False,
#  'rep': False,
#  'checked': False,
#  'wifi': False,
#  'done': False,
#  'business': False,
#  'upgrade': False,
#  'point': False,
#  'anyone': False,
#  'thing': False,
#  '....': False,
#  'fee': False,
#  'looking': False,
#  'come': False,
#  'person': False,
#  'via': False,
#  'also': False,
#  '30': False,
#  'missing': False,
#  'always': False,
#  'every': False,
#  'awesome': False,
#  'board': False,
#  'option': False,
#  'lax': False,
#  'employee': False,
#  'credit': False,
#  'appreciate': False,
#  'team': False,
#  'app': False,
#  '6': False,
#  'terrible': False,
#  'southwest': False,
#  'status': False,
#  'delta': False,
#  'understand': False,
#  'gt': False,
#  'show': False,
#  'yesterday': False,
#  '1st': False,
#  '20': False,
#  '10': False,
#  'mean': False,
#  'without': False,
#  'working': False,
#  'claim': False,
#  'making': False,
#  'thx': False,
#  'suck': False,
#  'leave': False,
#  'instead': False,
#  'happy': False,
#  'sorry': False,
#  'send': False,
#  'friend': False,
#  'disappointed': False,
#  'ok': False,
#  'name': False,
#  'earlier': False,
#  'open': False,
#  'speak': False,
#  'almost': False,
#  'many': False,
#  'full': False,
#  'money': False,
#  'took': False,
#  'ridiculous': False,
#  'phl': False,
#  'dca': False,
#  'helpful': False,
#  'fail': False,
#  'sfo': False,
#  'something': False,
#  'airway': False,
#  'extra': False,
#  'talk': False,
#  'try': False,
#  'connecting': False,
#  'rt': False,
#  'member': False,
#  'amazing': False,
#  'pas': False,
#  'departure': False,
#  'unacceptable': False,
#  'hung': False,
#  'policy': False,
#  'add': False,
#  'oh': False,
#  'wife': False,
#  'stranded': False,
#  'la': False,
#  'family': False,
#  'hi': False,
#  'though': False,
#  'available': False,
#  'reason': False,
#  'site': False,
#  'ground': False,
#  'lot': False,
#  'fix': False,
#  'seriously': False,
#  'everyone': False,
#  'paid': False,
#  'company': False,
#  'month': False,
#  'least': False,
#  'early': False,
#  'direct': False,
#  'old': False,
#  'stop': False,
#  'found': False,
#  'tweet': False,
#  'vega': False,
#  'chicago': False,
#  'horrible': False,
#  'ord': False,
#  'taking': False,
#  'card': False,
#  'supposed': False,
#  'message': False,
#  'snow': False,
#  'dallas': False,
#  'ewr': False,
#  'contact': False,
#  'denver': False,
#  'food': False,
#  'ur': False,
#  'big': False,
#  'san': False,
#  'chance': False,
#  'kid': False,
#  'received': False,
#  'twitter': False,
#  'clt': False,
#  'w/': True,
#  'offer': False,
#  'question': False,
#  'past': False,
#  'actually': False,
#  'tarmac': False,
#  'charge': False,
#  'calling': False,
#  'boston': False,
#  'sit': False,
#  'different': False,
#  'row': False,
#  'destinationdragons': False,
#  'away': False,
#  'saying': False,
#  'poor': False,
#  '--': False,
#  'wrong': False,
#  'account': False,
#  'cost': False,
#  'leaving': False,
#  'start': False,
#  'desk': False,
#  'bos': False,
#  'american': False,
#  'might': False,
#  'job': False,
#  'phx': False,
#  'enough': False,
#  'link': False,
#  'complaint': False,
#  '7': False,
#  'maybe': False,
#  'twice': False,
#  'hey': False,
#  'little': False,
#  '45': False,
#  'stay': False,
#  'asked': False,
#  'car': False,
#  'telling': False,
#  'reply': False,
#  'soon': False,
#  'far': False,
#  'runway': False,
#  '8': False,
#  'changed': False,
#  'landed': False,
#  'three': False,
#  'return': False,
#  'around': False,
#  'went': False,
#  '50': False,
#  'gave': False,
#  'confirmation': False,
#  'frustrated': False,
#  'guess': False,
#  'using': False,
#  'terminal': False,
#  'iad': False,
#  'destination': False,
#  'nyc': False,
#  'used': False,
#  'feel': False,
#  'waited': False,
#  'may': False,
#  'believe': False,
#  'city': False,
#  'coming': False,
#  '40': False,
#  'price': False,
#  'possible': False,
#  'plan': False,
#  'bc': True,
#  'plus': False,
#  'traveling': False,
#  'together': False,
#  'cool': False,
#  'im': False,
#  'charlotte': False,
#  'thought': False,
#  'seems': False,
#  'swa': False,
#  'else': False,
#  'computer': False,
#  'second': False,
#  'less': False,
#  'real': False,
#  'idea': False,
#  'high': False,
#  'w': False,
#  '200': False,
#  'deal': False,
#  'hard': False,
#  'landing': False,
#  'thru': False,
#  'room': False,
#  'vacation': False,
#  'frustrating': False,
#  'end': False,
#  'houston': False,
#  'place': False,
#  'longer': False,
#  'newark': False,
#  'hang': False,
#  'apology': False,
#  'sat': False,
#  'tv': False,
#  'hear': False,
#  '15': False,
#  'arrive': False,
#  'happened': False,
#  'mechanical': False,
#  'half': False,
#  'na': False,
#  'easy': False,
#  'reach': False,
#  'process': False,
#  'broken': False,
#  'arrived': False,
#  'fare': False,
#  'error': False,
#  'assistance': False,
#  'busy': False,
#  'philly': False,
#  'group': False,
#  'flyer': False,
#  'fll': False,
#  'international': False,
#  'ua': False,
#  'cust': False,
#  'scheduled': False,
#  'heard': False,
#  'dc': False,
#  'counting': False,
#  'leg': False,
#  'date': False,
#  'awful': False,
#  'forward': False,
#  'club': False,
#  'award': False,
#  'given': False,
#  'lga': False,
#  'reflight': False,
#  'joke': False,
#  'lol': False,
#  'child': False,
#  'maintenance': False,
#  'request': False,
#  'jet': False,
#  'appreciated': False,
#  'glad': False,
#  'lack': False,
#  'bring': False,
#  'traveler': False,
#  'pls': False,
#  'human': False,
#  'monday': False,
#  'miami': False,
#  'rock': False,
#  'ask': False,
#  'b': False,
#  'lt': False,
#  'lose': False,
#  'iah': False,
#  'paying': False,
#  'information': False,
#  'flew': False,
#  'spent': False,
#  '25': False,
#  'everything': False,
#  'checking': False,
#  '2nd': False,
#  'standby': False,
#  "y'all": False,
#  'situation': False,
#  'run': False,
#  'tsa': False,
#  'loyal': False,
#  'respond': False,
#  '1/2': False,
#  'quick': False,
#  'drive': False,
#  'carry': False,
#  'cause': False,
#  '24': False,
#  'hoping': False,
#  'hopefully': False,
#  'storm': False,
#  'blue': False,
#  'ceo': False,
#  'original': False,
#  'yeah': False,
#  'super': False,
#  'case': False,
#  'platinum': False,
#  'wow': False,
#  'fine': False,
#  'companion': False,
#  'expect': False,
#  'word': False,
#  'switch': False,
#  'seem': False,
#  'wtf': False,
#  'supervisor': False,
#  'entire': False,
#  'whole': False,
#  'pick': False,
#  'bwi': False,
#  'medium': False,
#  'luv': False,
#  'currently': False,
#  'rather': False,
#  'imaginedragons': False,
#  'wanted': False,
#  'okay': False,
#  'priority': False,
#  'boarded': False,
#  '800': False,
#  'atl': False,
#  'unitedairlines': False,
#  'sunday': False,
#  'asking': False,
#  'usair': False,
#  '9': False,
#  'cant': False,
#  'counter': False,
#  'wish': False,
#  'correct': False,
#  'orlando': False,
#  'flightlations': False,
#  'beyond': False,
#  'detail': False,
#  'communication': False,
#  'husband': False,
#  'live': False,
#  'safety': False,
#  'helping': False,
#  'part': False,
#  'treat': False,
#  'empty': False,
#  'completely': False,
#  'provide': False,
#  'world': False,
#  'asap': False,
#  'apparently': False,
#  'holding': False,
#  'figure': False,
#  'life': False,
#  'fixed': False,
#  'must': False,
#  'flighting': False,
#  'offered': False,
#  'drink': False,
#  'lie': False,
#  'hate': False,
#  'load': False,
#  'reschedule': False,
#  'form': False,
#  'fun': False,
#  'austin': False,
#  'sleep': False,
#  'worry': False,
#  '1.5': False,
#  'gon': False,
#  'middle': False,
#  'r': False,
#  'happen': False,
#  'moved': False,
#  '12': False,
#  'disconnected': False,
#  'upset': False,
#  'purchase': False,
#  'buy': False,
#  'pretty': False,
#  'address': False,
#  'zero': False,
#  'nashville': False,
#  'list': False,
#  'several': False,
#  'helped': False,
#  'taken': False,
#  'land': False,
#  'tuesday': False,
#  'c': False,
#  'dont': False,
#  'space': False,
#  'happens': False,
#  'door': False,
#  'ready': False,
#  'kind': False,
#  '100': False,
#  'losing': False,
#  'flown': False,
#  'yr': False,
#  'support': False,
#  'access': False,
#  'small': False,
#  'top': False,
#  'future': False,
#  'mom': False,
#  'customerservice': False,
#  '11': False,
#  'probably': False,
#  'needed': False,
#  'explain': False,
#  'compensation': False,
#  'answering': False,
#  'confirmed': False,
#  'delivered': False,
#  'route': False,
#  'matter': False,
#  'despite': False,
#  'running': False,
#  'water': False,
#  'spoke': False,
#  'allow': False,
#  'report': False,
#  'fault': False,
#  '1k': False,
#  'share': False,
#  'aircraft': False,
#  'huge': False,
#  'news': False,
#  'page': False,
#  'sw': False,
#  'dividend': False,
#  'overhead': False,
#  'automated': False,
#  'virgin': False,
#  'mine': False,
#  'responding': False,
#  'cold': False,
#  'item': False,
#  'knew': False,
#  'unable': False,
#  'following': False,
#  'atlanta': False,
#  'den': False,
#  'clothes': False,
#  'cover': False,
#  'mileage': False,
#  'absolutely': False,
#  'daughter': False,
#  'id': False,
#  'either': False,
#  'schedule': False,
#  'changing': False,
#  'course': False,
#  'notification': False,
#  'country': False,
#  'checkin': False,
#  'arrival': False,
#  'sad': False,
#  'haha': False,
#  'record': False,
#  'yall': False,
#  'fact': False,
#  'overnight': False,
#  'inconvenience': False,
#  'giving': False,
#  'handle': False,
#  'meal': False,
#  'attitude': False,
#  'rescheduled': False,
#  'son': False,
#  'mess': False,
#  'set': False,
#  'complete': False,
#  'extremely': False,
#  'man': False,
#  'learn': False,
#  'baby': False,
#  'drop': False,
#  'luck': False,
#  'code': False,
#  'check-in': False,
#  'unfortunately': False,
#  'confirm': False,
#  'note': False,
#  'usairwaysfail': False,
#  'read': False,
#  'sending': False,
#  'program': False,
#  'folk': False,
#  'area': False,
#  'lounge': False,
#  'excited': False,
#  'birthday': False,
#  'connect': False,
#  'saw': False,
#  'letting': False,
#  'treated': False,
#  'kept': False,
#  'seen': False,
#  'rate': False,
#  'multiple': False,
#  'friday': False,
#  'fl': False,
#  'bought': False,
#  'true': False,
#  '2015': False,
#  'watch': False,
#  'step': False,
#  'flightlation': False,
#  'layover': False,
#  'b/c': False,
#  'wonderful': False,
#  'mco': False,
#  'excuse': False,
#  'failure': False,
#  'allowed': False,
#  'dragon': False,
#  'social': False,
#  'trouble': False,
#  'concern': False,
#  'acceptable': False,
#  'mobile': False,
#  'charged': False,
#  'hello': False,
#  'forced': False,
#  'sign': False,
#  '3rd': False,
#  'afternoon': False,
#  'none': False,
#  'showing': False,
#  'fan': False,
#  'story': False,
#  'frequent': False,
#  'resolved': False,
#  'resolve': False,
#  'receive': False,
#  'failed': False,
#  'caused': False,
#  'depart': False,
#  'choice': False,
#  'totally': False,
#  'mistake': False,
#  'front': False,
#  'crazy': False,
#  'tag': False,
#  'enjoy': False,
#  'close': False,
#  'volume': False,
#  'refuse': False,
#  'cabin': False,
#  'arriving': False,
#  'happening': False,
#  'gold': False,
#  'file': False,
#  'web': False,
#  'shit': False,
#  'excellent': False,
#  'dealing': False,
#  'pm': False,
#  'rdu': False,
#  'round': False,
#  'explanation': False,
#  'mind': False,
#  'held': False,
#  'tix': False,
#  '2hrs': False,
#  'came': False,
#  '2.5': False,
#  'non': False,
#  'receipt': False,
#  'office': False,
#  'neveragain': False,
#  'bna': False,
#  'kudos': False,
#  'merger': False,
#  'americanairlines': False,
#  'tmrw': False,
#  'winter': False,
#  'evening': False,
#  'ice': False,
#  'bank': False,
#  'warm': False,
#  'submitted': False,
#  'started': False,
#  '75': False,
#  'behind': False,
#  'offering': False,
#  'touch': False,
#  'four': False,
#  'unhappy': False,
#  'especially': False,
#  'post': False,
#  'wall': False,
#  'lady': False,
#  'window': False,
#  '90': False,
#  'btw': False,
#  'entertainment': False,
#  'ruined': False,
#  'plz': False,
#  'mia': False,
#  'ppl': False,
#  'gone': False,
#  '2+': False,
#  'others': False,
#  'philadelphia': False,
#  'phoenix': False,
#  'ny': False,
#  'nope': False,
#  'bumped': False,
#  'willing': False,
#  'relation': False,
#  'closed': False,
#  'move': False,
#  'tired': False,
#  'added': False,
#  'catch': False,
#  'spend': False,
#  'followed': False,
#  'short': False,
#  'transfer': False,
#  'weekend': False,
#  'view': False,
#  'funeral': False,
#  'nonstop': False,
#  'friendly': False,
#  'video': False,
#  'worth': False,
#  'itinerary': False,
#  'callback': False,
#  'emergency': False,
#  'updated': False,
#  'bus': False,
#  'current': False,
#  'low': False,
#  'sick': False,
#  'moving': False,
#  'seating': False,
#  'visit': False,
#  'feb': False,
#  'order': False,
#  'anyway': False,
#  'denied': False,
#  'finger': False,
#  'saturday': False,
#  'wondering': False,
#  'letter': False,
#  'text': False,
#  'bin': False,
#  'mention': False,
#  'sound': False,
#  'count': False,
#  'broke': False,
#  'solution': False,
#  'turn': False,
#  'airplane': False,
#  'unhelpful': False,
#  'favorite': False,
#  'center': False,
#  'fuck': False,
#  'cut': False,
#  'march': False,
#  'head': False,
#  'suggestion': False,
#  'per': False,
#  'funny': False,
#  'final': False,
#  'captain': False,
#  'announcement': False,
#  'train': False,
#  'ended': False,
#  'tho': False,
#  'hand': False,
#  'svc': False,
#  'conf': False,
#  'dollar': False,
#  'notice': False,
#  'assist': False,
#  'special': False,
#  'enter': False,
#  'takeoff': False,
#  'filed': False,
#  'bit': False,
#  'department': False,
#  'flightd': False,
#  'literally': False,
#  'imagine': False,
#  'seattle': False,
#  'control': False,
#  'sense': False,
#  'tweeting': False,
#  'resolution': False,
#  'save': False,
#  'kidding': False,
#  'safe': False,
#  'badservice': False,
#  'inflight': False,
#  'win': False,
#  'break': False,
#  'useless': False,
#  'sort': False,
#  'definitely': False,
#  'onto': False,
#  'power': False,
#  'match': False,
#  '.....': False,
#  'america': False,
#  'pathetic': False,
#  'state': False,
#  'actual': False,
#  'reward': False,
#  'large': False,
#  'talked': False,
#  'fyi': False,
#  'auto': False,
#  'inside': False,
#  'surprise': False,
#  'departing': False,
#  'clear': False,
#  'worked': False,
#  'hell': False,
#  'except': False,
#  'nightmare': False,
#  'security': False,
#  'oscar': False,
#  'trust': False,
#  'damn': False,
#  'brand': False,
#  'fast': False,
#  'engine': False,
#  'planned': False,
#  'equipment': False,
#  'fair': False,
#  'effort': False,
#  'photo': False,
#  'incredibly': False,
#  'internet': False,
#  'impressed': False,
#  'however': False,
#  'smh': False,
#  'florida': False,
#  'diego': False,
#  'snack': False,
#  'clearly': False,
#  'serious': False,
#  'expected': False,
#  'representative': False,
#  'anymore': False,
#  'discount': False,
#  'anywhere': False,
#  'carrier': False,
#  'select': False,
#  'premier': False,
#  'n': False,
#  'freezing': False,
#  'south': False,
#  'dept': False,
#  'delivery': False,
#  'expensive': False,
#  'angry': False,
#  'w/o': False,
#  'compensate': False,
#  'consider': False,
#  'fit': False,
#  'answered': False,
#  'game': False,
#  'handled': False,
#  'ugh': False,
#  'avgeek': False,
#  'notified': False,
#  ...}

# %%
training_data = [(get_feature_dict(doc), category) for doc, category in training_documents]
testing_data = [(get_feature_dict(doc), category) for doc, category in test_documents]

# %%
training_data_orig = [(get_feature_dict(doc), category) for doc, category in training_documents_orig]
testing_data_orig = [(get_feature_dict(doc)) for doc in test_documents_orig]

# %%
#testing_data_orig[3659]

# %%
#training_data_orig[0][0]

# %%
from nltk import NaiveBayesClassifier

# %%
clalassifier = NaiveBayesClassifier.train(training_data)

# %%
#testing_data[0][0]

# %%
print(clalassifier.classify(testing_data_orig[2]))
# Out:
# negative

# %%
nltk.classify.accuracy(clalassifier, testing_data)
# Out:
# 0.7768844221105528

# %%
clalassifier.classify(testing_data[0][0])
# Out:
# 'negative'

# %% [markdown]
# # Predicting the actual test values from original Test data provided

# %%
from nltk.classify.scikitlearn import SklearnClassifier

# %%
from nltk import NaiveBayesClassifier
classfier1 = NaiveBayesClassifier.train(training_data_orig)

# %%
predictions2=[]
for i in range(len(testing_data_orig)):
    predictions2.append(classfier1.classify(testing_data_orig[i]))

# %%
len(predictions2)
# Out:
# 3660

# %%
import pandas as pd
df1= pd.DataFrame(predictions2)
df1.to_csv('twitter_pred3.csv',header=False,index=False)
